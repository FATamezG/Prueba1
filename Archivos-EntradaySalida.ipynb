# %%
#1.- athlete_events.csv
#2.- PopularCreativeTypes.csv

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
datos1=pd.read_csv("C:\Users\francisco.tamez\OneDrive - CEMEX\Paco Tamez\Downloads\athlete_events.csv")
# Out:
#   File "<ipython-input-4-3fdba3e6deca>", line 1
#     datos1=pd.read_csv("C:\Users\francisco.tamez\OneDrive - CEMEX\Paco Tamez\Downloads\athlete_events.csv")
#                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
#\U es una cadena de caracteres reservada

# %%
datos1=pd.read_csv("athlete_events.csv")

# %%
datos2=pd.read_csv("PopularCreativeTypes.csv")

# %%
datos1
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
datos2
# Out:
#    RANK           CREATIVE TYPES MOVIES      TOTAL GROSS AVERAGE GROSS  \
# 0   1.0     Contemporary Fiction  7,442  $96,203,727,036   $12,927,133
# 1   2.0             Kids Fiction    564  $32,035,539,746   $56,800,602
# 2   3.0          Science Fiction    724  $29,922,660,857   $41,329,642
# 3   4.0                  Fantasy    759  $21,724,062,575   $28,621,953
# 4   5.0               Super Hero    129  $20,273,157,911  $157,156,263
# 5   6.0       Historical Fiction  1,487  $18,521,260,744   $12,455,454
# 6   7.0            Dramatization  1,175  $15,715,191,699   $13,374,631
# 7   8.0                  Factual  2,467   $2,960,327,207    $1,199,970
# 8   9.0  Multiple Creative Types     42     $117,574,526    $2,799,393
# 9   NaN                      NaN    NaN              NaN           NaN
#
#   MARKET SHARE
# 0       40.46%
# 1       13.47%
# 2       12.59%
# 3        9.14%
# 4        8.53%
# 5        7.79%
# 6        6.61%
# 7        1.25%
# 8        0.05%
# 9          NaN

# %%
datos1["Games"].unique().tolist()
# Out:
# ['1992 Summer',
#  '2012 Summer',
#  '1920 Summer',
#  '1900 Summer',
#  '1988 Winter',
#  '1992 Winter',
#  '1994 Winter',
#  '1932 Summer',
#  '2002 Winter',
#  '1952 Summer',
#  '1980 Winter',
#  '2000 Summer',
#  '1996 Summer',
#  '1912 Summer',
#  '1924 Summer',
#  '2014 Winter',
#  '1948 Summer',
#  '1998 Winter',
#  '2006 Winter',
#  '2008 Summer',
#  '2016 Summer',
#  '2004 Summer',
#  '1960 Winter',
#  '1964 Winter',
#  '1984 Winter',
#  '1984 Summer',
#  '1968 Summer',
#  '1972 Summer',
#  '1988 Summer',
#  '1936 Summer',
#  '1952 Winter',
#  '1956 Winter',
#  '1956 Summer',
#  '1960 Summer',
#  '1928 Summer',
#  '1976 Summer',
#  '1980 Summer',
#  '1964 Summer',
#  '2010 Winter',
#  '1968 Winter',
#  '1906 Summer',
#  '1972 Winter',
#  '1976 Winter',
#  '1924 Winter',
#  '1904 Summer',
#  '1928 Winter',
#  '1908 Summer',
#  '1948 Winter',
#  '1932 Winter',
#  '1936 Winter',
#  '1896 Summer']

# %%
datos1["Sport"]=="Judo"
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: Sport, Length: 271116, dtype: bool

# %%
datosjudo=datos1[datos1["Sport"]=="Judo"]

# %%
datosfut=datos1[datos1["Sport"]=="Football"]

# %%
datosfut
# Out:
#             ID                               Name Sex   Age  Height  Weight  \
# 2            3                Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 105         37                 Ann Kristin Aarnes   F  23.0   182.0    64.0
# 116         41                           Rolf Aas   M  28.0     NaN     NaN
# 157         61                   Stefan Abadzhiev   M  26.0   175.0    72.0
# 178         76         Jouan Patrice Abanda Etong   M  22.0   185.0    82.0
# ...        ...                                ...  ..   ...     ...     ...
# 270810  135438               Manuel Ziga Fernndez   M  20.0   172.0    69.0
# 270843  135455                    Vjekoslav upani   M  19.0     NaN     NaN
# 270901  135476                  Emily Jane Zurrer   F  21.0   179.0    69.0
# 270982  135504  Viktor Oleksandrovych Zviahintsev   M  25.0   178.0    79.0
# 271107  135566         James Francis "Jim" Zylker   M  21.0   175.0    75.0
#
# ...

# %%
datosfut["Sex"].count()
# Out:
# 6745

# %%
datosfut["Sex"].value_counts()
# Out:
# M    5733
# F    1012
# Name: Sex, dtype: int64

# %%
datosfut["Age"].max()
# Out:
# 40.0

# %%
datosfut["Age"].min()
# Out:
# 15.0

# %%
datosfut[datosfut["Age"]==40.0]
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 155668   78145  Margarete Maria "Meg" Pioresan   F  40.0   175.0    64.0
# 262097  131136                    Oros Witarsa   M  40.0     NaN     NaN
#
#              Team  NOC        Games  Year  Season       City     Sport  \
# 155668     Brazil  BRA  1996 Summer  1996  Summer    Atlanta  Football
# 262097  Indonesia  INA  1956 Summer  1956  Summer  Melbourne  Football
#
#                             Event Medal
# 155668  Football Women's Football   NaN
# 262097    Football Men's Football   NaN

# %%
datosfut[datosfut["Age"]==15.0]
# Out:
#             ID                                     Name Sex   Age  Height  \
# 128439   64677                      Samuel Osei Kuffour   M  15.0   175.0
# 156711   78727                        Louis John Menges   M  15.0     NaN
# 180261   90593                        Chatchai Paholpat   M  15.0   169.0
# 188957   94914                      Chirawat Pimpawatin   M  15.0   166.0
# 208319  104558  Abdel-Karim Muhammad Mahmoud Ezzat Sakr   M  15.0     NaN
#
#         Weight                           Team  NOC        Games  Year  Season  \
# 128439    75.0                          Ghana  GHA  1992 Summer  1992  Summer
# 156711     NaN  Christian Brothers' College-1  USA  1904 Summer  1904  Summer
# 180261    54.0                       Thailand  THA  1968 Summer  1968  Summer
# 188957    60.0                       Thailand  THA  1968 Summer  1968  Summer
# 208319     NaN                          Egypt  EGY  1936 Summer  1936  Summer
#
# ...

# %%
datosfut.sort_values(by=["Weight"])
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 268586  134370  Albert Ferdinand "Al" Zerhusen   M  24.0   183.0    28.0
# 103855   52546             Tawa Bolanle Ishola   F  19.0   160.0    45.0
# 164358   82510         Linda Maserame Motlhalo   F  18.0   162.0    47.0
# 196365   98583         Lebohang Ester Ramalepe   F  24.0   155.0    48.0
# 176013   88475                      Vera Okolo   F  19.0   161.0    48.0
# ...        ...                             ...  ..   ...     ...     ...
# 270443  135272                      Zou Wenzhi   M   NaN     NaN     NaN
# 270478  135289            Zzimo Alves Calazans   M  20.0     NaN     NaN
# 270661  135361     Abdullah Sulaiman Zubromawi   M  22.0   176.0     NaN
# 270718  135386                      Enea Zuffi   M  20.0     NaN     NaN
# 270843  135455                 Vjekoslav upani   M  19.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season            City  \
# ...

# %%
datosfut.sort_values(by=["Age"])
# Out:
#             ID                                     Name Sex   Age  Height  \
# 128439   64677                      Samuel Osei Kuffour   M  15.0   175.0
# 180261   90593                        Chatchai Paholpat   M  15.0   169.0
# 188957   94914                      Chirawat Pimpawatin   M  15.0   166.0
# 156711   78727                        Louis John Menges   M  15.0     NaN
# 208319  104558  Abdel-Karim Muhammad Mahmoud Ezzat Sakr   M  15.0     NaN
# ...        ...                                      ...  ..   ...     ...
# 268805  134485                             Zhang Jinhai   M   NaN     NaN
# 269530  134866                            Zhu Yongqiang   M   NaN     NaN
# 269870  135025                      Francisc Zimmermann   M   NaN     NaN
# 270443  135272                               Zou Wenzhi   M   NaN     NaN
# 270456  135283         Mohamed Abdel Rahman Tati Zouita   M   NaN   174.0
#
#         Weight                           Team  NOC        Games  Year  Season  \
# ...

# %%
datosfut.sort_values(by=["Age"])
# Out:
#             ID                                     Name Sex   Age  Height  \
# 128439   64677                      Samuel Osei Kuffour   M  15.0   175.0
# 180261   90593                        Chatchai Paholpat   M  15.0   169.0
# 188957   94914                      Chirawat Pimpawatin   M  15.0   166.0
# 156711   78727                        Louis John Menges   M  15.0     NaN
# 208319  104558  Abdel-Karim Muhammad Mahmoud Ezzat Sakr   M  15.0     NaN
# ...        ...                                      ...  ..   ...     ...
# 268805  134485                             Zhang Jinhai   M   NaN     NaN
# 269530  134866                            Zhu Yongqiang   M   NaN     NaN
# 269870  135025                      Francisc Zimmermann   M   NaN     NaN
# 270443  135272                               Zou Wenzhi   M   NaN     NaN
# 270456  135283         Mohamed Abdel Rahman Tati Zouita   M   NaN   174.0
#
#         Weight                           Team  NOC        Games  Year  Season  \
# ...

# %%
OrdAge=datosfut.sort_values(by=["Age"])
OrdAge[OrdAge["Age"].notna()]
# Out:
#             ID                                     Name Sex   Age  Height  \
# 128439   64677                      Samuel Osei Kuffour   M  15.0   175.0
# 180261   90593                        Chatchai Paholpat   M  15.0   169.0
# 188957   94914                      Chirawat Pimpawatin   M  15.0   166.0
# 156711   78727                        Louis John Menges   M  15.0     NaN
# 208319  104558  Abdel-Karim Muhammad Mahmoud Ezzat Sakr   M  15.0     NaN
# ...        ...                                      ...  ..   ...     ...
# 79208    40223              Ryan Joseph Giggs (Wilson-)   M  38.0   180.0
# 188286   94587                Ricardo Piccinini Alburez   M  39.0   185.0
# 22001    11600               Jenny Lynn Bindon (Bourn-)   F  39.0   170.0
# 155668   78145           Margarete Maria "Meg" Pioresan   F  40.0   175.0
# 262097  131136                             Oros Witarsa   M  40.0     NaN
#
#         Weight                           Team  NOC        Games  Year  Season  \
# ...

# %%
datosfut[datosfut["Age"].notna()].sort_values(by=["Age"])
# Out:
#             ID                                     Name Sex   Age  Height  \
# 128439   64677                      Samuel Osei Kuffour   M  15.0   175.0
# 180261   90593                        Chatchai Paholpat   M  15.0   169.0
# 188957   94914                      Chirawat Pimpawatin   M  15.0   166.0
# 156711   78727                        Louis John Menges   M  15.0     NaN
# 208319  104558  Abdel-Karim Muhammad Mahmoud Ezzat Sakr   M  15.0     NaN
# ...        ...                                      ...  ..   ...     ...
# 79208    40223              Ryan Joseph Giggs (Wilson-)   M  38.0   180.0
# 188286   94587                Ricardo Piccinini Alburez   M  39.0   185.0
# 22001    11600               Jenny Lynn Bindon (Bourn-)   F  39.0   170.0
# 155668   78145           Margarete Maria "Meg" Pioresan   F  40.0   175.0
# 262097  131136                             Oros Witarsa   M  40.0     NaN
#
#         Weight                           Team  NOC        Games  Year  Season  \
# ...
